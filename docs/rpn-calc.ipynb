# %% [markdown]
# # RPN Calculator demo

# %% [markdown]
# Go ahead and tap the keys below, the calculator should work *in any browser*. The purpose of this notebook is to demonstrate the *source* which relies on **JavaScript**. The GitHub repository is at https://github.com/rsvp/rpn-calc

# %%
source = 'https://raw.githubusercontent.com/rsvp/rpn-calc/master/rpn-calc-js.html'
#  "rpn-calc-js.html" is latest stand-alone file under development.
#  The user interface looks better when it's rendered directly.

#  Here we display the skeletal html containing the JavaScript code:
from IPython.display import HTML 
HTML( source )
#  Note: Python is NOT used in the calculator itself.
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>RPN Calculator :: Reverse Polish Notation in Javascript</title>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <meta http-equiv="Content-language" content="en">
# <meta name="author" content="Paul Lutus, 1996 | Adriano, 2009-">
# <meta name="description" content="RPN Calculator, Reverse Polish Notation, JavaScript application">
# <meta name="menuCat" content="JavaScript">
# <meta name="keywords" content="calculator,rpn, reverse polish notation">
# <meta name="ROBOTS" content="NOINDEX, NOFOLLOW">
# <meta name="ROBOTS" content="NOARCHIVE, NOSNIPPET">
# <meta name="ROBOTS" content="NOYDIR, NOODP">
# <!-- ==================================================================
#
# CHANGE LOG
# 2015-06-11  v15.06  Clarify project history.
#                        Enhance ENTER and register areas by color.
#                        Use unicode to beautify some buttons.
# ...

# %% [markdown]
# ## FAQ: What is RPN?
#
# RPN stands for "**Reverse Polish Notation**," a parenthesis-free method for performing calculations. This method has been popularized by Hewlett-Packard which makes hand-held RPN calculators. The method depends on a stack of values as its organizing principle. When a number is entered, the previous entry is "raised" in the stack so that several values can be stored. When a mathematical operation is performed, it is performed on the most recent value (or values, if more than one is required).
#
# For example, to subtract 8 from 10:
#
#      10
#      ENTER
#      8
#      -
#
# There are no worries about the algebraic order of precedence because the order in which operations are performed is entirely controlled by the order in which the values are entered and the operations performed.
#
# In the next example we will multiply the result of two additions: ((9 + 8) * (7 + 6)). To solve this problem on an algebraic calculator, you must carefully place parentheses between the operations, assuming your calculator has parentheses -- but in RPN notation the problem is simple to solve without parentheses:
#
#      9
#      ENTER
#      8
#      +
#      7
#      ENTER
#      6
#      +
#      x
#
# You never have to press more keys than on an algebraic calculator, and you often press far fewer using RPN.

# %% [markdown]
# ### Appendix

# %% [markdown]
# If you want a free RPN calculator for your Android, we would recommend *Droid48*. Our use case is designed for quick browser convenience.
#
# To fix bugs, please make your pull requests to https://github.com/rsvp/rpn-calc Your feedback is welcome. Thanks!

# %% [markdown]
#
# *CHANGE LOG*
#
#     2015-06-12  For testing, this notebook should be run whenever source
#                    is modified. The source is indeed embedded herein
#                    (not freshly downloaded from GitHub per each access).
#                    GitHub has problems rendering this notebook probably
#                    because the embedded html conflicts with their site.
#                    Using nbviewer.ipython.org will work, so the use
#                    shortner https://git.io/rpn-calc.ipynb for raw notebook.
#                       v15.06 is currently embedded here.
#     2015-06-10  Calculator embedded within this IPython notebook.
#                    The calculator itself has no Python dependencies.
